# %% [markdown]
# # Zonal Stats (spatial mean)

# %% [markdown]
# ## ET

# %%
import glob
import matplotlib.pyplot as plt
import geopandas as geopandas
from rasterstats import zonal_stats
import pandas as pd
import numpy as np

# %%
import geopandas as geopandas
from rasterstats import zonal_stats
path = 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Aglar_ET'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means1 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Aglar.shp", i, stats="mean") # we can use: min max min count sum std median majority minority unique range nodata percentile
    means1.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\MODIS_ET_mm\\Aglar_ET\\1_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Aglar_ET\\2_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Aglar_ET\\3_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Aglar_ET\\4_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Aglar_ET\\5_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Aglar_ET\\6_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Aglar_ET\\7_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Aglar_ET\\8_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Aglar_ET\\9_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Aglar_ET\\10_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Aglar_ET\\11_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Aglar_ET\\12_ERA5_ET_sum_Mean_4326_mm.tif']

# %%
means1
# Out:
# [[{'mean': 19.679449529621152}],
#  [{'mean': 26.950737350622937}],
#  [{'mean': 32.661206458174426}],
#  [{'mean': 27.158558988049837}],
#  [{'mean': 25.142918891431478}],
#  [{'mean': 41.78775108060005}],
#  [{'mean': 93.7995041952708}],
#  [{'mean': 109.75640732265447}],
#  [{'mean': 90.38718853292653}],
#  [{'mean': 41.0177822273074}],
#  [{'mean': 25.821322781591658}],
#  [{'mean': 17.053016145436057}]]

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
list_of_values_Aglar = [item[0]['mean'] for item in means1]
df1 = pd.DataFrame(list_of_values_Aglar)
df1.insert(0, "Months", months, True)
df1.to_csv("E:\\Rachit\\NWH\\MODIS_ET_mm\\Aglar_monthly_mean.csv")

# %%
plt.figure(figsize=(10,5))
plt.plot(months, list_of_values_Aglar)
plt.title('Mean ET for Aglar')
plt.ylabel('Evapotranspiration (in mm)')
# Out:
# Text(0, 0.5, 'Evapotranspiration (in mm)')

# %%
path = 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Asan_ET'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means2 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Asan.shp", i, stats="mean")
    means2.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\MODIS_ET_mm\\Asan_ET\\1_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Asan_ET\\2_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Asan_ET\\3_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Asan_ET\\4_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Asan_ET\\5_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Asan_ET\\6_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Asan_ET\\7_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Asan_ET\\8_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Asan_ET\\9_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Asan_ET\\10_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Asan_ET\\11_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Asan_ET\\12_ERA5_ET_sum_Mean_4326_mm.tif']

# %%
means2
# Out:
# [[{'mean': 25.692581778365806}],
#  [{'mean': 36.87229344404398}],
#  [{'mean': 35.61828550572563}],
#  [{'mean': 17.51544930577733}],
#  [{'mean': 12.614284410785164}],
#  [{'mean': 30.498667822437156}],
#  [{'mean': 87.61501741259487}],
#  [{'mean': 107.14592666940402}],
#  [{'mean': 89.18156089845948}],
#  [{'mean': 44.8723907720851}],
#  [{'mean': 33.04139179098804}],
#  [{'mean': 22.62222120838846}]]

# %%
list_of_valuesAsan = [item[0]['mean'] for item in means2]
df2 = pd.DataFrame(list_of_valuesAsan)
df2.insert(0, "Months", months, True)
df2.to_csv("E:\\Rachit\\NWH\\MODIS_ET_mm\\Asan_monthly_mean.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesAsan)
plt.title('Mean ET for Asan')
plt.ylabel('Evapotranspiration (in mm)')
# Out:
# Text(0, 0.5, 'Evapotranspiration (in mm)')

# %%
path = 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Beas_Manali_MODIS_ET'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means3 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Beas_Manali.shp", i, stats="mean")
    means3.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\MODIS_ET_mm\\Beas_Manali_MODIS_ET\\1_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Beas_Manali_MODIS_ET\\2_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Beas_Manali_MODIS_ET\\3_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Beas_Manali_MODIS_ET\\4_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Beas_Manali_MODIS_ET\\5_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Beas_Manali_MODIS_ET\\6_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Beas_Manali_MODIS_ET\\7_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Beas_Manali_MODIS_ET\\8_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Beas_Manali_MODIS_ET\\9_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Beas_Manali_MODIS_ET\\10_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Beas_Manali_MODIS_ET\\11_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Beas_Manali_MODIS_
# ...

# %%
means3
# Out:
# [[{'mean': 29.78306212747285}],
#  [{'mean': 36.434394997623144}],
#  [{'mean': 48.27422752038615}],
#  [{'mean': 48.68050243171097}],
#  [{'mean': 64.22400628953817}],
#  [{'mean': 81.06462866127913}],
#  [{'mean': 98.3875379383479}],
#  [{'mean': 92.26916297948588}],
#  [{'mean': 57.1603429992321}],
#  [{'mean': 25.811822137711633}],
#  [{'mean': 25.598325227630088}],
#  [{'mean': 24.55895345010422}]]

# %%
list_of_valuesBeas_Manali = [item[0]['mean'] for item in means3]
df3 = pd.DataFrame(list_of_valuesBeas_Manali)
df3.insert(0, "Months", months, True)
df3.to_csv("E:\\Rachit\\NWH\\MODIS_ET_mm\\Beas_Manali_monthly_mean.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesBeas_Manali)
plt.title('Mean ET for Beas Manali')
plt.ylabel('Evapotranspiration (in mm)')
# Out:
# Text(0, 0.5, 'Evapotranspiration (in mm)')

# %%
path = 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Gangotri_ET'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means4 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Gangotri.shp", i, stats="mean")
    means4.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\MODIS_ET_mm\\Gangotri_ET\\1_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Gangotri_ET\\2_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Gangotri_ET\\3_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Gangotri_ET\\4_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Gangotri_ET\\5_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Gangotri_ET\\6_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Gangotri_ET\\7_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Gangotri_ET\\8_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Gangotri_ET\\9_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Gangotri_ET\\10_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Gangotri_ET\\11_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Gangotri_ET\\12_ERA5_ET_sum_Mean_4326_mm.tif']

# %%
means4
# Out:
# [[{'mean': 35.509965919653006}],
#  [{'mean': 42.86871837240525}],
#  [{'mean': 53.97686667355159}],
#  [{'mean': 56.48156563048643}],
#  [{'mean': 80.66606423629041}],
#  [{'mean': 104.70561809356606}],
#  [{'mean': 115.52237942786326}],
#  [{'mean': 105.40614478983787}],
#  [{'mean': 68.7526489724259}],
#  [{'mean': 37.8843953320252}],
#  [{'mean': 34.836827429515644}],
#  [{'mean': 31.20807600950119}]]

# %%
list_of_valuesGangotri = [item[0]['mean'] for item in means4]
df4 = pd.DataFrame(list_of_valuesGangotri)
df4.insert(0, "Months", months, True)
df4.to_csv("E:\\Rachit\\NWH\\MODIS_ET_mm\\Gangotri_monthly_mean.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesGangotri)
plt.title('Mean ET for Gangotri')
plt.ylabel('Evapotranspiration (in mm)')
# Out:
# Text(0, 0.5, 'Evapotranspiration (in mm)')

# %%
path = 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Hanval_ET'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means5 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Hanval.shp", i, stats="mean")
    means5.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\MODIS_ET_mm\\Hanval_ET\\1_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Hanval_ET\\2_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Hanval_ET\\3_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Hanval_ET\\4_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Hanval_ET\\5_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Hanval_ET\\6_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Hanval_ET\\7_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Hanval_ET\\8_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Hanval_ET\\9_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Hanval_ET\\10_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Hanval_ET\\11_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Hanval_ET\\12_ERA5_ET_sum_Mean_4326_mm.tif']

# %%
means5
# Out:
# [[{'mean': 22.461910915171785}],
#  [{'mean': 28.84940711462451}],
#  [{'mean': 29.38496123441775}],
#  [{'mean': 18.317459714198847}],
#  [{'mean': 14.101740650653696}],
#  [{'mean': 32.840183186378844}],
#  [{'mean': 92.05883627242322}],
#  [{'mean': 110.55748707813926}],
#  [{'mean': 97.13192839768928}],
#  [{'mean': 49.7470393736698}],
#  [{'mean': 33.29060884767407}],
#  [{'mean': 21.636169808452422}]]

# %%
list_of_valuesHanval = [item[0]['mean'] for item in means5]
df5 = pd.DataFrame(list_of_valuesHanval)
df5.insert(0, "Months", months, True)
df5.to_csv("E:\\Rachit\\NWH\\MODIS_ET_mm\\Hanval_monthly_mean.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesHanval)
plt.title('Mean ET for Hanval')
plt.ylabel('Evapotranspiration (in mm)')
# Out:
# Text(0, 0.5, 'Evapotranspiration (in mm)')

# %%
path = 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Jhelum_ET'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means6 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Jhelum.shp", i, stats="mean")
    means6.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\MODIS_ET_mm\\Jhelum_ET\\1_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Jhelum_ET\\2_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Jhelum_ET\\3_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Jhelum_ET\\4_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Jhelum_ET\\5_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Jhelum_ET\\6_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Jhelum_ET\\7_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Jhelum_ET\\8_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Jhelum_ET\\9_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Jhelum_ET\\10_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Jhelum_ET\\11_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Jhelum_ET\\12_ERA5_ET_sum_Mean_4326_mm.tif']

# %%
means6
# Out:
# [[{'mean': 28.358572796210378}],
#  [{'mean': 36.18071755662504}],
#  [{'mean': 38.32845482423062}],
#  [{'mean': 35.32880966942345}],
#  [{'mean': 48.49372148758366}],
#  [{'mean': 59.90891564754926}],
#  [{'mean': 79.8450633945416}],
#  [{'mean': 79.16164689661731}],
#  [{'mean': 45.01242131059327}],
#  [{'mean': 16.50752155111867}],
#  [{'mean': 16.455910808947635}],
#  [{'mean': 18.934097770439795}]]

# %%
list_of_valuesJhelum = [item[0]['mean'] for item in means6]
df6 = pd.DataFrame(list_of_valuesJhelum)
df6.insert(0, "Months", months, True)
df6.to_csv("E:\\Rachit\\NWH\\MODIS_ET_mm\\Jhelum_monthly_mean.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesJhelum)
plt.title('Mean ET for Jhelum')
plt.ylabel('Evapotranspiration (in mm)')
# Out:
# Text(0, 0.5, 'Evapotranspiration (in mm)')

# %%
path = 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Parbati_ET'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means7 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Parbati.shp", i, stats="mean")
    means7.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\MODIS_ET_mm\\Parbati_ET\\1_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Parbati_ET\\2_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Parbati_ET\\3_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Parbati_ET\\4_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Parbati_ET\\5_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Parbati_ET\\6_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Parbati_ET\\7_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Parbati_ET\\8_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Parbati_ET\\9_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Parbati_ET\\10_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Parbati_ET\\11_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Parbati_ET\\12_ERA5_ET_sum_Mean_4326_mm.tif']

# %%
means7
# Out:
# [[{'mean': 30.51502760963626}],
#  [{'mean': 38.53623335952284}],
#  [{'mean': 48.61660672590659}],
#  [{'mean': 47.47417752055507}],
#  [{'mean': 64.4125366560802}],
#  [{'mean': 88.75816061172775}],
#  [{'mean': 111.1947934533624}],
#  [{'mean': 105.0767215908462}],
#  [{'mean': 66.2916175152434}],
#  [{'mean': 28.541102393572878}],
#  [{'mean': 26.11985459293769}],
#  [{'mean': 24.942487855079843}]]

# %%
list_of_valuesParbati = [item[0]['mean'] for item in means7]
df7 = pd.DataFrame(list_of_valuesParbati)
df7.insert(0, "Months", months, True)
df7.to_csv("E:\\Rachit\\NWH\\MODIS_ET_mm\\Parbati_monthly_mean.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesParbati)
plt.title('Mean ET for Parbati')
plt.ylabel('Evapotranspiration (in mm)')
# Out:
# Text(0, 0.5, 'Evapotranspiration (in mm)')

# %%
path = 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Suketi_ET'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means8 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Suketi.shp", i, stats="mean")
    means8.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\MODIS_ET_mm\\Suketi_ET\\1_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Suketi_ET\\2_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Suketi_ET\\3_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Suketi_ET\\4_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Suketi_ET\\5_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Suketi_ET\\6_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Suketi_ET\\7_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Suketi_ET\\8_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Suketi_ET\\9_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Suketi_ET\\10_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Suketi_ET\\11_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Suketi_ET\\12_ERA5_ET_sum_Mean_4326_mm.tif']

# %%
means8
# Out:
# [[{'mean': 17.40737632703405}],
#  [{'mean': 26.772380071362495}],
#  [{'mean': 40.661406986476365}],
#  [{'mean': 34.473172987974095}],
#  [{'mean': 29.382743050966916}],
#  [{'mean': 44.25207479846703}],
#  [{'mean': 102.99901766442008}],
#  [{'mean': 120.82164442095063}],
#  [{'mean': 98.15121580547113}],
#  [{'mean': 37.47308708867451}],
#  [{'mean': 21.153634201136512}],
#  [{'mean': 14.240438747191755}]]

# %%
list_of_valuesSuketi = [item[0]['mean'] for item in means8]
df8 = pd.DataFrame(list_of_valuesSuketi)
df8.insert(0, "Months", months, True)
df8.to_csv("E:\\Rachit\\NWH\\MODIS_ET_mm\\Suketi_monthly_mean.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesSuketi)
plt.title('Mean ET for Suketi')
plt.ylabel('Evapotranspiration (in mm)')
# Out:
# Text(0, 0.5, 'Evapotranspiration (in mm)')

# %%
path = 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Tawi_ET'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means9 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Tawi.shp", i, stats="mean")
    means9.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\MODIS_ET_mm\\Tawi_ET\\1_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Tawi_ET\\2_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Tawi_ET\\3_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Tawi_ET\\4_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Tawi_ET\\5_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Tawi_ET\\6_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Tawi_ET\\7_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Tawi_ET\\8_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Tawi_ET\\9_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Tawi_ET\\10_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Tawi_ET\\11_ERA5_ET_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\MODIS_ET_mm\\Tawi_ET\\12_ERA5_ET_sum_Mean_4326_mm.tif']

# %%
means9
# Out:
# [[{'mean': 16.657774143067236}],
#  [{'mean': 24.097564482069462}],
#  [{'mean': 28.331172461254194}],
#  [{'mean': 24.99473773520872}],
#  [{'mean': 24.804213959802407}],
#  [{'mean': 29.479738112296847}],
#  [{'mean': 64.86005694030696}],
#  [{'mean': 84.09195105396132}],
#  [{'mean': 63.05214374599344}],
#  [{'mean': 24.104103190165542}],
#  [{'mean': 14.717744824465479}],
#  [{'mean': 11.467340868811041}]]

# %%
list_of_valuesTawi = [item[0]['mean'] for item in means9]
df8 = pd.DataFrame(list_of_valuesTawi)
df8.insert(0, "Months", months, True)
df8.to_csv("E:\\Rachit\\NWH\\MODIS_ET_mm\\Tawi_monthly_mean.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesTawi)
plt.title('Mean ET for Tawi')
plt.ylabel('Evapotranspiration (in mm)')
# Out:
# Text(0, 0.5, 'Evapotranspiration (in mm)')

# %% [markdown]
# # Zonal Stats SM

# %%
import glob
import matplotlib.pyplot as plt
import geopandas as geopandas
from rasterstats import zonal_stats
import pandas as pd
import numpy as np

# %%
import geopandas as geopandas
from rasterstats import zonal_stats
path = "E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Aglar"
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means1 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Aglar.shp", i, stats="mean")
    means1.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Aglar\\01_jan_sm_avg_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Aglar\\02_feb_sm_avg_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Aglar\\03_mar_sm_avg_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Aglar\\04_apr_sm_avg_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Aglar\\05_may_sm_avg_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Aglar\\06_jun_sm_avg_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Aglar\\07_jul_sm_avg_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Aglar\\08_aug_sm_avg_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Aglar\\09_sep_sm_avg_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Aglar\\10_oct_sm_avg_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Aglar\\11_nov_sm_avg_EPSG_4326_clip4326.ti
# ...

# %%
means1
# Out:
# [[{'mean': 0.2458169664655413}],
#  [{'mean': 0.27709157126290457}],
#  [{'mean': 0.24087769644601004}],
#  [{'mean': 0.2019352776663644}],
#  [{'mean': 0.19912681579589844}],
#  [{'mean': 0.23407835279192243}],
#  [{'mean': 0.32634925842285156}],
#  [{'mean': 0.35191099984305246}],
#  [{'mean': 0.32884957449776786}],
#  [{'mean': 0.25004754747663227}],
#  [{'mean': 0.19172043119158064}],
#  [{'mean': 0.19326725006103515}]]

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
list_of_values_Aglar_SM = [item[0]['mean'] for item in means1]
df1 = pd.DataFrame(list_of_values_Aglar_SM)
df1.insert(0, "Months", months, True)
df1.to_csv("E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Aglar_monthly_mean_SM.csv")

# %%
plt.figure(figsize=(10,5))
plt.plot(months, list_of_values_Aglar_SM)
plt.title('Mean Soil Moisture for Aglar')
plt.ylabel('Soil Moisture (% fraction)')
# Out:
# Text(0, 0.5, 'Soil Moisture (% fraction)')

# %%
path = 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Asan'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means2 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Asan.shp", i, stats="mean")
    means2.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Asan\\01_jan_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Asan\\02_feb_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Asan\\03_mar_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Asan\\04_apr_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Asan\\05_may_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Asan\\06_jun_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Asan\\07_jul_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Asan\\08_aug_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Asan\\09_sep_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Asan\\10_oct_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Asan\\11_nov_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Asan\\
# ...

# %%
means2
# Out:
# [[{'mean': 0.1819195400010671}],
#  [{'mean': 0.2054380707393419}],
#  [{'mean': 0.17546020912018834}],
#  [{'mean': 0.12705728391937862}],
#  [{'mean': 0.1074327885709851}],
#  [{'mean': 0.14286953250303963}],
#  [{'mean': 0.2515919666416598}],
#  [{'mean': 0.2879173329334385}],
#  [{'mean': 0.2569497721084696}],
#  [{'mean': 0.19214602337767747}],
#  [{'mean': 0.14648760865066227}],
#  [{'mean': 0.14682311253831876}]]

# %%
list_of_valuesAsan_SM = [item[0]['mean'] for item in means2]
df2 = pd.DataFrame(list_of_valuesAsan_SM)
df2.insert(0, "Months", months, True)
df2.to_csv("E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Asan_monthly_mean_SM.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesAsan_SM)
plt.title('Mean Soil Moisture for Asan')
plt.ylabel('Soil Moisture (% fraction)')
# Out:
# Text(0, 0.5, 'Soil Moisture (% fraction)')

# %%
path = 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Beas_Manali'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means3 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Beas_Manali.shp", i, stats="mean")
    means3.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Beas_Manali\\01_jan_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Beas_Manali\\02_feb_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Beas_Manali\\03_mar_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Beas_Manali\\04_apr_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Beas_Manali\\05_may_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Beas_Manali\\06_jun_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Beas_Manali\\07_jul_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Beas_Manali\\08_aug_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Beas_Manali\\09_sep_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Beas_Manali\\10_oct_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Beas_Manali\\11_nov_sm
# ...

# %%
means3
# Out:
# [[{'mean': 0.296048187628025}],
#  [{'mean': 0.30010776984982374}],
#  [{'mean': 0.3099527126405297}],
#  [{'mean': 0.3247096829298066}],
#  [{'mean': 0.3304219594815882}],
#  [{'mean': 0.32732817021811883}],
#  [{'mean': 0.3289806784653082}],
#  [{'mean': 0.3326225048158227}],
#  [{'mean': 0.3113900161370998}],
#  [{'mean': 0.2899016403570408}],
#  [{'mean': 0.29212211981052305}],
#  [{'mean': 0.2940425407595751}]]

# %%
list_of_valuesBeas_Manali_SM = [item[0]['mean'] for item in means3]
df3 = pd.DataFrame(list_of_valuesBeas_Manali_SM)
df3.insert(0, "Months", months, True)
df3.to_csv("E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Beas_Manali_monthly_mean_SM.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesBeas_Manali_SM)
plt.title('Mean Soil Moisture for Beas Manali')
plt.ylabel('Soil Moisture (% fraction)')
# Out:
# Text(0, 0.5, 'Soil Moisture (% fraction)')

# %%
path = 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Gangotri'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means4 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Gangotri.shp", i, stats="mean")
    means4.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Gangotri\\01_jan_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Gangotri\\02_feb_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Gangotri\\03_mar_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Gangotri\\04_apr_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Gangotri\\05_may_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Gangotri\\06_jun_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Gangotri\\07_jul_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Gangotri\\08_aug_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Gangotri\\09_sep_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Gangotri\\10_oct_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Gangotri\\11_nov_sm_avg_clip_EPSG_4326.tif', 'E:\\Ra
# ...

# %%
means4
# Out:
# [[{'mean': 0.5680127217673665}],
#  [{'mean': 0.567762061907411}],
#  [{'mean': 0.5682261086100764}],
#  [{'mean': 0.5703973445360875}],
#  [{'mean': 0.5738581607216283}],
#  [{'mean': 0.5779889464009288}],
#  [{'mean': 0.5826150049735149}],
#  [{'mean': 0.5832136408094282}],
#  [{'mean': 0.5766485350050793}],
#  [{'mean': 0.5709733992538216}],
#  [{'mean': 0.5694966980547359}],
#  [{'mean': 0.5686451820397156}]]

# %%
list_of_valuesGangotri_SM = [item[0]['mean'] for item in means4]
df4 = pd.DataFrame(list_of_valuesGangotri_SM)
df4.insert(0, "Months", months, True)
df4.to_csv("E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Gangotri_monthly_mean_SM.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesGangotri_SM)
plt.title('Mean Soil Moisture for Gangotri')
plt.ylabel('Soil Moisture (% fraction)')
# Out:
# Text(0, 0.5, 'Soil Moisture (% fraction)')

# %%
path = 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Hanval'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means5 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Hanval.shp", i, stats="mean")
    means5.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Hanval\\01_jan_sm_avg_clip_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Hanval\\02_feb_sm_avg_clip_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Hanval\\03_mar_sm_avg_clip_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Hanval\\04_apr_sm_avg_clip_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Hanval\\05_may_sm_avg_clip_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Hanval\\06_jun_sm_avg_clip_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Hanval\\07_jul_sm_avg_clip_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Hanval\\08_aug_sm_avg_clip_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Hanval\\09_sep_sm_avg_clip_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Hanval\\10_oct_sm_avg_clip_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_av
# ...

# %%
means5
# Out:
# [[{'mean': 0.22969747591419382}],
#  [{'mean': 0.2607678485517742}],
#  [{'mean': 0.2254964684237953}],
#  [{'mean': 0.192375375443146}],
#  [{'mean': 0.18630599975585938}],
#  [{'mean': 0.22977431481625854}],
#  [{'mean': 0.3326810628426175}],
#  [{'mean': 0.35565082966780465}],
#  [{'mean': 0.3334249929219735}],
#  [{'mean': 0.2571625268759848}],
#  [{'mean': 0.18825558253696986}],
#  [{'mean': 0.18086742753742122}]]

# %%
list_of_valuesHanval_SM = [item[0]['mean'] for item in means5]
df5 = pd.DataFrame(list_of_valuesHanval_SM)
df5.insert(0, "Months", months, True)
df5.to_csv("E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Hanval_monthly_mean_SM.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesHanval_SM)
plt.title('Mean Soil Moisture for Hanval')
plt.ylabel('Soil Moisture (% fraction)')
# Out:
# Text(0, 0.5, 'Soil Moisture (% fraction)')

# %%
path = 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Jhelum'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means6 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Jhelum.shp", i, stats="mean")
    means6.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Jhelum\\01_jan_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Jhelum\\02_feb_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Jhelum\\03_mar_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Jhelum\\04_apr_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Jhelum\\05_may_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Jhelum\\06_jun_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Jhelum\\07_jul_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Jhelum\\08_aug_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Jhelum\\09_sep_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Jhelum\\10_oct_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Jhelum\\11_nov_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_aver
# ...

# %%
means6
# Out:
# [[{'mean': 0.26511569731374074}],
#  [{'mean': 0.2830530844986995}],
#  [{'mean': 0.2908487965461313}],
#  [{'mean': 0.29626254629387405}],
#  [{'mean': 0.2804000916534621}],
#  [{'mean': 0.2501808427447082}],
#  [{'mean': 0.24903713063000776}],
#  [{'mean': 0.25940960361979787}],
#  [{'mean': 0.24487792268035458}],
#  [{'mean': 0.224059474664965}],
#  [{'mean': 0.23370034328005412}],
#  [{'mean': 0.24881024510060393}]]

# %%
list_of_valuesJhelum_SM = [item[0]['mean'] for item in means6]
df6 = pd.DataFrame(list_of_valuesJhelum_SM)
df6.insert(0, "Months", months, True)
df6.to_csv("E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Jhelum_monthly_mean_SM.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesJhelum_SM)
plt.title('Mean Soil Moisture for Jhelum')
plt.ylabel('Soil Moisture (% fraction)')
# Out:
# Text(0, 0.5, 'Soil Moisture (% fraction)')

# %%
path = 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Parbati'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means7 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Parbati.shp", i, stats="mean")
    means7.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Parbati\\01_jan_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Parbati\\02_feb_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Parbati\\03_mar_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Parbati\\04_apr_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Parbati\\05_may_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Parbati\\06_jun_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Parbati\\07_jul_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Parbati\\08_aug_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Parbati\\09_sep_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Parbati\\10_oct_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Parbati\\11_nov_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\
# ...

# %%
means7
# Out:
# [[{'mean': 0.4265351323888185}],
#  [{'mean': 0.4317422896374963}],
#  [{'mean': 0.43499152055087903}],
#  [{'mean': 0.43653958744599225}],
#  [{'mean': 0.43605130619599225}],
#  [{'mean': 0.4355656802299054}],
#  [{'mean': 0.44879397732140197}],
#  [{'mean': 0.45477098503612934}],
#  [{'mean': 0.4381724415575648}],
#  [{'mean': 0.419206185051028}],
#  [{'mean': 0.41788581784490464}],
#  [{'mean': 0.42025178493276966}]]

# %%
list_of_valuesParbati_SM = [item[0]['mean'] for item in means7]
df7 = pd.DataFrame(list_of_valuesParbati_SM)
df7.insert(0, "Months", months, True)
df7.to_csv("E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Parbati_monthly_mean_SM.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesParbati_SM)
plt.title('Mean Soil Moisture for Parbati')
plt.ylabel('Soil Moisture (% fraction)')
# Out:
# Text(0, 0.5, 'Soil Moisture (% fraction)')

# %%
path = 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Suketi'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means8 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Suketi.shp", i, stats="mean")
    means8.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Suketi\\01_jan_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Suketi\\02_feb_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Suketi\\03_mar_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Suketi\\04_apr_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Suketi\\05_may_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Suketi\\06_jun_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Suketi\\07_jul_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Suketi\\08_aug_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Suketi\\09_sep_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Suketi\\10_oct_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Suketi\\11_nov_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_aver
# ...

# %%
means8
# Out:
# [[{'mean': 0.2079959617653474}],
#  [{'mean': 0.23114598463029426}],
#  [{'mean': 0.21235226858690912}],
#  [{'mean': 0.17119009724728346}],
#  [{'mean': 0.13951349984570807}],
#  [{'mean': 0.14216374624804193}],
#  [{'mean': 0.2247555340607154}],
#  [{'mean': 0.25497823802347713}],
#  [{'mean': 0.22522053984821144}],
#  [{'mean': 0.16530901526436587}],
#  [{'mean': 0.14301397836752955}],
#  [{'mean': 0.15851550416898003}]]

# %%
list_of_valuesSuketi_SM = [item[0]['mean'] for item in means8]
df8 = pd.DataFrame(list_of_valuesSuketi_SM)
df8.insert(0, "Months", months, True)
df8.to_csv("E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Suketi_monthly_mean_SM.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesSuketi_SM)
plt.title('Mean Soil Moisture for Suketi')
plt.ylabel('Soil Moisture (% fraction)')
# Out:
# Text(0, 0.5, 'Evapotranspiration (in mm)')

# %%
path = 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Tawi'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means9 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Tawi.shp", i, stats="mean")
    means9.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Tawi\\01_jan_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Tawi\\02_feb_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Tawi\\03_mar_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Tawi\\04_apr_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Tawi\\05_may_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Tawi\\06_jun_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Tawi\\07_jul_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Tawi\\08_aug_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Tawi\\09_sep_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Tawi\\10_oct_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Tawi\\11_nov_sm_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Tawi\\
# ...

# %%
means9
# Out:
# [[{'mean': 0.27668362029834087}],
#  [{'mean': 0.30828040800114936}],
#  [{'mean': 0.2813355663437833}],
#  [{'mean': 0.2402092581873001}],
#  [{'mean': 0.20280573668002067}],
#  [{'mean': 0.2104774751642874}],
#  [{'mean': 0.29330079946944965}],
#  [{'mean': 0.32582765754097814}],
#  [{'mean': 0.2780628326350946}],
#  [{'mean': 0.20456109931474048}],
#  [{'mean': 0.20037145553621402}],
#  [{'mean': 0.2306321394214752}]]

# %%
list_of_valuesTawi_SM = [item[0]['mean'] for item in means9]
df8 = pd.DataFrame(list_of_valuesTawi_SM)
df8.insert(0, "Months", months, True)
df8.to_csv("E:\\Rachit\\NWH\\Montly_average\\SM_cliped\\Tawi_monthly_mean_SM.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesTawi_SM)
plt.title('Mean Soil Moisture for Tawi')
plt.ylabel('Soil Moisture (% fraction)')
# Out:
# Text(0, 0.5, 'Soil Moisture (% fraction)')

# %% [markdown]
# # Zonal Stats Temp

# %%
import glob
import matplotlib.pyplot as plt
import geopandas as geopandas
from rasterstats import zonal_stats
import pandas as pd
import numpy as np

# %%
path = "E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Aglar"
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means1 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Aglar.shp", i, stats="mean")
    means1.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Aglar\\01_jan_temp_avg_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Aglar\\02_feb_temp_avg_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Aglar\\03_mar_temp_avg_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Aglar\\04_apr_temp_avg_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Aglar\\05_may_temp_avg_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Aglar\\06_jun_temp_avg_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Aglar\\07_jul_temp_avg_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Aglar\\08_aug_temp_avg_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Aglar\\09_sep_temp_avg_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Aglar\\10_oct_temp_avg_EPSG_4326_clip4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Tem
# ...

# %%
means1
# Out:
# [[{'mean': 278.88342633928573}],
#  [{'mean': 281.540234375}],
#  [{'mean': 286.160546875}],
#  [{'mean': 290.9341517857143}],
#  [{'mean': 294.0939732142857}],
#  [{'mean': 295.45541294642857}],
#  [{'mean': 293.62293526785714}],
#  [{'mean': 292.6294084821429}],
#  [{'mean': 291.1160435267857}],
#  [{'mean': 287.54190848214284}],
#  [{'mean': 283.590625}],
#  [{'mean': 280.37589285714284}]]

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
list_of_values_Aglar_T = [item[0]['mean'] for item in means1]
df1 = pd.DataFrame(list_of_values_Aglar_T)
df1.insert(0, "Months", months, True)
df1.to_csv("E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Aglar_monthly_mean_T.csv")

# %%
plt.figure(figsize=(10,5))
plt.plot(months, list_of_values_Aglar_T)
plt.title('Mean Temperature for Aglar')
plt.ylabel('Temperature (in Kelvin)')
# Out:
# Text(0, 0.5, 'Temperature (in Kelvin)')

# %%
path = "E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Asan"
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means2 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Asan.shp", i, stats="mean")
    means2.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Asan\\01_jan_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Asan\\02_feb_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Asan\\03_mar_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Asan\\04_apr_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Asan\\05_may_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Asan\\06_jun_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Asan\\07_jul_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Asan\\08_aug_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Asan\\09_sep_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Asan\\10_oct_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Asan\\11_nov_temp_avg_clip_EPSG_4326.ti
# ...

# %%
means2
# Out:
# [[{'mean': 284.69417425496687}],
#  [{'mean': 287.94989134933775}],
#  [{'mean': 293.10316639072846}],
#  [{'mean': 298.6117032284768}],
#  [{'mean': 301.99904283940396}],
#  [{'mean': 303.02835264900665}],
#  [{'mean': 300.3516659768212}],
#  [{'mean': 298.95783319536423}],
#  [{'mean': 297.5955608443709}],
#  [{'mean': 293.9701469370861}],
#  [{'mean': 289.68281767384104}],
#  [{'mean': 286.03062913907286}]]

# %%
list_of_valuesAsan_T = [item[0]['mean'] for item in means2]
df2 = pd.DataFrame(list_of_valuesAsan_T)
df2.insert(0, "Months", months, True)
df2.to_csv("E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Asan_monthly_mean_T.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesAsan_T)
plt.title('Mean Temperature for Asan')
plt.ylabel('Temperature (in Kelvin)')
# Out:
# Text(0, 0.5, 'Temperature (in Kelvin)')

# %%
path = 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Beas_Manali'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means3 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Beas_Manali.shp", i, stats="mean")
    means3.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Beas_Manali\\01_jan_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Beas_Manali\\02_feb_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Beas_Manali\\03_mar_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Beas_Manali\\04_apr_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Beas_Manali\\05_may_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Beas_Manali\\06_jun_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Beas_Manali\\07_jul_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Beas_Manali\\08_aug_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Beas_Manali\\09_sep_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Beas_Manali\\10_oct_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\
# ...

# %%
means3
# Out:
# [[{'mean': 263.297256097561}],
#  [{'mean': 265.4995474466463}],
#  [{'mean': 268.8063309832317}],
#  [{'mean': 272.4439310213415}],
#  [{'mean': 276.2364233993902}],
#  [{'mean': 280.709365472561}],
#  [{'mean': 283.9388100228659}],
#  [{'mean': 283.8449885670732}],
#  [{'mean': 280.6538681402439}],
#  [{'mean': 274.5125285823171}],
#  [{'mean': 269.2172732469512}],
#  [{'mean': 265.2958508003049}]]

# %%
list_of_valuesBeas_Manali_T = [item[0]['mean'] for item in means3]
df3 = pd.DataFrame(list_of_valuesBeas_Manali_T)
df3.insert(0, "Months", months, True)
df3.to_csv("E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Beas_Manali_monthly_mean_T.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesBeas_Manali_T)
plt.title('Mean Temperature for Beas_Manali')
plt.ylabel('Temperature (in Kelvin)')
# Out:
# Text(0, 0.5, 'Temperature (in Kelvin)')

# %%
path = 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Gangotri'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means4 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Gangotri.shp", i, stats="mean")
    means4.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Gangotri\\01_jan_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Gangotri\\02_feb_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Gangotri\\03_mar_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Gangotri\\04_apr_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Gangotri\\05_may_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Gangotri\\06_jun_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Gangotri\\07_jul_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Gangotri\\08_aug_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Gangotri\\09_sep_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Gangotri\\10_oct_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\
# ...

# %%
means4
# Out:
# [[{'mean': 253.78434597523218}],
#  [{'mean': 255.85025638544892}],
#  [{'mean': 259.0453753869969}],
#  [{'mean': 262.74758126934984}],
#  [{'mean': 266.42124613003097}],
#  [{'mean': 271.0342734133127}],
#  [{'mean': 274.18527476780184}],
#  [{'mean': 274.1500822368421}],
#  [{'mean': 271.2956898219814}],
#  [{'mean': 264.58528444272446}],
#  [{'mean': 259.5670472136223}],
#  [{'mean': 255.88133707430342}]]

# %%
list_of_valuesGangotri_T = [item[0]['mean'] for item in means4]
df4 = pd.DataFrame(list_of_valuesGangotri_T)
df4.insert(0, "Months", months, True)
df4.to_csv("E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Gangotri_monthly_mean_T.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesGangotri_T)
plt.title('Mean Temperature for Gangotri')
plt.ylabel('Temperature (in Kelvin)')
# Out:
# Text(0, 0.5, 'Temperature (in Kelvin)')

# %%
path = 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Hanval'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means5 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Hanval.shp", i, stats="mean")
    means5.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Hanval\\01_jan_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Hanval\\02_feb_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Hanval\\03_mar_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Hanval\\04_apr_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Hanval\\05_may_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Hanval\\06_jun_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Hanval\\07_jul_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Hanval\\08_aug_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Hanval\\09_sep_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Hanval\\10_oct_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Hanval\\11_nov_temp
# ...

# %%
means5
# Out:
# [[{'mean': 281.0843618697479}],
#  [{'mean': 283.9114036239496}],
#  [{'mean': 288.6930475315126}],
#  [{'mean': 293.6523109243698}],
#  [{'mean': 296.8783482142857}],
#  [{'mean': 298.01779149159665}],
#  [{'mean': 295.77521008403363}],
#  [{'mean': 294.73027179621846}],
#  [{'mean': 293.22708771008405}],
#  [{'mean': 289.6624212184874}],
#  [{'mean': 285.68418461134456}],
#  [{'mean': 282.4094669117647}]]

# %%
list_of_valuesHanval_T = [item[0]['mean'] for item in means5]
df5 = pd.DataFrame(list_of_valuesHanval_T)
df5.insert(0, "Months", months, True)
df5.to_csv("E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Hanval_monthly_mean_T.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesHanval_T)
plt.title('Mean Temperature for Hanval')
plt.ylabel('Temperature (in Kelvin)')
# Out:
# Text(0, 0.5, 'Temperature (in Kelvin)')

# %%
path = 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Jhelum'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means6 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Jhelum.shp", i, stats="mean")
    means6.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Jhelum\\01_jan_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Jhelum\\02_feb_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Jhelum\\03_mar_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Jhelum\\04_apr_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Jhelum\\05_may_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Jhelum\\06_jun_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Jhelum\\07_jul_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Jhelum\\08_aug_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Jhelum\\09_sep_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Jhelum\\10_oct_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Jhelum\\11_nov_temp
# ...

# %%
means6
# Out:
# [[{'mean': 269.31726859602963}],
#  [{'mean': 271.57459339870843}],
#  [{'mean': 275.8089571872758}],
#  [{'mean': 279.8862413298254}],
#  [{'mean': 283.7887766084669}],
#  [{'mean': 287.44068404687874}],
#  [{'mean': 289.2317926333413}],
#  [{'mean': 288.3164314757235}],
#  [{'mean': 285.51118153551784}],
#  [{'mean': 280.4408933269553}],
#  [{'mean': 275.604550346807}],
#  [{'mean': 271.57758311408753}]]

# %%
list_of_valuesJhelum_T = [item[0]['mean'] for item in means6]
df6 = pd.DataFrame(list_of_valuesJhelum_T)
df6.insert(0, "Months", months, True)
df6.to_csv("E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Jhelum_monthly_mean_T.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesJhelum_T)
plt.title('Mean Temperature for Jhelum')
plt.ylabel('Temperature (in Kelvin)')
# Out:
# Text(0, 0.5, 'Temperature (in Kelvin)')

# %%
path = 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Parbati'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means7 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Parbati.shp", i, stats="mean")
    means7.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Parbati\\01_jan_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Parbati\\02_feb_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Parbati\\03_mar_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Parbati\\04_apr_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Parbati\\05_may_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Parbati\\06_jun_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Parbati\\07_jul_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Parbati\\08_aug_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Parbati\\09_sep_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Parbati\\10_oct_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Parbati\\
# ...

# %%
means7
# Out:
# [[{'mean': 260.62488825983314}],
#  [{'mean': 262.9396230631704}],
#  [{'mean': 266.47420664481524}],
#  [{'mean': 270.13701206793803}],
#  [{'mean': 273.59589168653156}],
#  [{'mean': 277.992122318236}],
#  [{'mean': 281.1924165673421}],
#  [{'mean': 281.10289407032184}],
#  [{'mean': 277.9137924612634}],
#  [{'mean': 271.5895411203814}],
#  [{'mean': 266.4349858462455}],
#  [{'mean': 262.7342073897497}]]

# %%
list_of_valuesParbati_T = [item[0]['mean'] for item in means7]
df7 = pd.DataFrame(list_of_valuesParbati_T)
df7.insert(0, "Months", months, True)
df7.to_csv("E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Parbati_monthly_mean_T.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesParbati_T)
plt.title('Mean Temperature for Parbati')
plt.ylabel('Temperature (in Kelvin)')
# Out:
# Text(0, 0.5, 'Temperature (in Kelvin)')

# %%
path = 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Suketi'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means8 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Suketi.shp", i, stats="mean")
    means8.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Suketi\\01_jan_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Suketi\\02_feb_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Suketi\\03_mar_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Suketi\\04_apr_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Suketi\\05_may_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Suketi\\06_jun_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Suketi\\07_jul_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Suketi\\08_aug_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Suketi\\09_sep_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Suketi\\10_oct_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Suketi\\11_nov_temp
# ...

# %%
means8
# Out:
# [[{'mean': 282.28662357233503}],
#  [{'mean': 284.87071700507613}],
#  [{'mean': 289.37712166878174}],
#  [{'mean': 294.3192615799492}],
#  [{'mean': 297.9160057106599}],
#  [{'mean': 299.8723429568528}],
#  [{'mean': 298.24399190989845}],
#  [{'mean': 296.83692893401013}],
#  [{'mean': 295.16973350253807}],
#  [{'mean': 291.4649825507614}],
#  [{'mean': 287.2857709390863}],
#  [{'mean': 283.79580425126903}]]

# %%
list_of_valuesSuketi_T = [item[0]['mean'] for item in means8]
df8 = pd.DataFrame(list_of_valuesSuketi_T)
df8.insert(0, "Months", months, True)
df8.to_csv("E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Suketi_monthly_mean_T.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesSuketi_T)
plt.title('Mean Temperature for Suketi')
plt.ylabel('Temperature (in Kelvin)')
# Out:
# Text(0, 0.5, 'Temperature (in Kelvin)')

# %%
path = 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Tawi'
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means9 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Tawi.shp", i, stats="mean")
    means9.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Tawi\\01_jan_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Tawi\\02_feb_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Tawi\\03_mar_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Tawi\\04_apr_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Tawi\\05_may_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Tawi\\06_jun_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Tawi\\07_jul_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Tawi\\08_aug_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Tawi\\09_sep_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Tawi\\10_oct_temp_avg_clip_EPSG_4326.tif', 'E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Tawi\\11_nov_temp_avg_clip_EPSG_4326.ti
# ...

# %%
means9
# Out:
# [[{'mean': 280.75839552238807}],
#  [{'mean': 283.0859541577825}],
#  [{'mean': 287.89045842217485}],
#  [{'mean': 292.96868336886996}],
#  [{'mean': 297.243736673774}],
#  [{'mean': 299.59518256929636}],
#  [{'mean': 298.40998134328356}],
#  [{'mean': 296.78887926439234}],
#  [{'mean': 294.93143656716416}],
#  [{'mean': 290.9563566098081}],
#  [{'mean': 286.3537446695096}],
#  [{'mean': 282.58785314498937}]]

# %%
list_of_valuesTawi_T = [item[0]['mean'] for item in means9]
df8 = pd.DataFrame(list_of_valuesTawi_T)
df8.insert(0, "Months", months, True)
df8.to_csv("E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Tawi_monthly_mean_T.csv")
plt.figure(figsize=(10,5))
plt.plot(months, list_of_valuesTawi_T)
plt.title('Mean Temperature for Tawi')
plt.ylabel('Temperature (in Kelvin)')
# Out:
# Text(0, 0.5, 'Temperature (in Kelvin)')

# %%
## looping for multiple files
import glob
import matplotlib.pyplot as plt
import geopandas as geopandas
from rasterstats import zonal_stats
import pandas as pd
import numpy as np

names=['Asan','Aglar','Gangotri','Hanval','Jhelum','Parbati','Suketi','Tawi','Beas_Manali']
for name in names:
    
    #infol=r"D:\Share\NWH\Chirps\\"+name+"_Chirps"
    path = r"E:\Rachit\FLDAS_forcodetest\output\ET"
    files = sorted(glob.glob(path+'\\*.tif'))
   
    #files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
    print(files)
    means1 = []
    for i in files:
        stats = zonal_stats(r"\\192.168.9.63\Share\NWH\shapefiles_watershed\\"+name+".shp", i, stats="mean") # we can use: min max min count sum std median majority minority unique range nodata percentile
        means1.append(stats)
        
        months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
        list_of_values_Aglar = [item[0]['mean'] for item in means1]
    df1 = pd.DataFrame(list_of_values_Aglar)
    df1.insert(0, "Months", months, True)
    df1.to_csv(r"E:\\Rachit\\FLDAS_forcodetest\\Graphs\\"+name+"_ET_means.csv")
    df1=None

# %% [markdown]
# ## Zonal Stats Precipitation

# %%
import glob
import matplotlib.pyplot as plt
import geopandas as geopandas
from rasterstats import zonal_stats
import pandas as pd
import numpy as np

names=['Asan','Aglar','Gangotri','Hanval','Jhelum','Parbati','Suketi','Tawi','Beas_Manali']
for name in names:
    
    #infol=r"D:\Share\NWH\Chirps\\"+name+"_Chirps"
    path = r"E:\Rachit\FLDAS_forcodetest\output\ET"
    files1 = glob.glob(path+'\\*.tif')
   
    files = sorted(files1, key=lambda x: int(''.join(filter(str.isdigit, x))))      # to sort properly according to numbers
    print(files)
    means1 = []
    months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
    for i in files:
        stats = zonal_stats(r"\\192.168.9.63\Share\NWH\shapefiles_watershed\\"+name+".shp", i, stats="mean") # we can use: min max min count sum std median majority minority unique range nodata percentile
        means1.append(stats)
    
        list_of_values_Aglar = [item[0]['mean'] for item in means1]
    df1 = pd.DataFrame(list_of_values_Aglar)
    df1.insert(0, "Months", months, True)
    df1.to_csv(r"E:\\Rachit\\FLDAS_forcodetest\\Graphs\\"+name+"_ET_means.csv")
    df1=None
    # plt.figure(figsize=(10,5))
    # plt.plot(months, list_of_values_pcp[i-1])
    # plt.title(f'Mean Precipitation for {i}')
    # plt.ylabel('Precipitation (in mm)')

# %%
import glob
import matplotlib.pyplot as plt
import geopandas as geopandas
from rasterstats import zonal_stats
import pandas as pd
import numpy as np

# %%
path = "E:\\Rachit\\NWH\\Runoff\\Aglar_ERA_Runoff"
files = sorted(glob.glob(path+'\\*.tif'))
files.sort(key=lambda x: int(x.split('\\')[-1].split('_')[0]))      # to sort properly according to numbers
print(files)
means1 = []
for i in files:
    stats = zonal_stats("E:\\Rachit\\NWH\\shapefiles_watershed\\Aglar.shp", i, stats="mean")
    means1.append(stats)
# Out:
# ['E:\\Rachit\\NWH\\Runoff\\Aglar_ERA_Runoff\\1_ERA5_Runoff_runoff_sum_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\Runoff\\Aglar_ERA_Runoff\\2_ERA5_Runoff_runoff_sum_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\Runoff\\Aglar_ERA_Runoff\\3_ERA5_Runoff_runoff_sum_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\Runoff\\Aglar_ERA_Runoff\\4_ERA5_Runoff_runoff_sum_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\Runoff\\Aglar_ERA_Runoff\\5_ERA5_Runoff_runoff_sum_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\Runoff\\Aglar_ERA_Runoff\\6_ERA5_Runoff_runoff_sum_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\Runoff\\Aglar_ERA_Runoff\\7_ERA5_Runoff_runoff_sum_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\Runoff\\Aglar_ERA_Runoff\\8_ERA5_Runoff_runoff_sum_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\Runoff\\Aglar_ERA_Runoff\\9_ERA5_Runoff_runoff_sum_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\Runoff\\Aglar_ERA_Runoff\\10_ERA5_Runoff_runoff_sum_sum_Mean_4326_mm.tif', 'E:\\Rachit\\NWH\\Runoff\\Aglar_ERA_Runoff\\11_ERA5_Runoff_runoff_sum_sum_Me
# ...

# %%
means1
# Out:
# [[{'mean': 13.327031857478692}],
#  [{'mean': 17.169267846884566}],
#  [{'mean': 15.942939400719188}],
#  [{'mean': 10.346726033813464}],
#  [{'mean': 7.592864056459124}],
#  [{'mean': 33.97123166724391}],
#  [{'mean': 179.87108251022073}],
#  [{'mean': 319.9381010502762}],
#  [{'mean': 176.41108555221777}],
#  [{'mean': 44.809278376539304}],
#  [{'mean': 17.868813018528567}],
#  [{'mean': 11.661683691445715}]]

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
list_of_values_Aglar_T = [item[0]['mean'] for item in means1]
df1 = pd.DataFrame(list_of_values_Aglar_T)
df1.insert(0, "Months", months, True)
df1.to_csv("E:\\Rachit\\NWH\\Montly_average\\Temp_clipped\\Aglar_monthly_mean_T.csv")

# %%
plt.figure(figsize=(10,5))
plt.plot(months, list_of_values_Aglar_T)
plt.title('Mean Temperature for Aglar')
plt.ylabel('Temperature (in Kelvin)')
# Out:
# Text(0, 0.5, 'Temperature (in Kelvin)')
